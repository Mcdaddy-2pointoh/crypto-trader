# %% [markdown]
# # 0. Imports

# %%
import ccxt
import pandas as pd
import matplotlib.pyplot as plt
import yaml
from exchange.exchange_utils import get_exchange, fetch_data
from portfolio.dynamic_stoploss import backtest
from strategy.dynamic_stoploss import apply_mca_dynamic_stoploss_strategy

# %% [markdown]
# # 1. Load Configs

# %%
def load_config(path="../config.yaml"):
    with open(path, "r") as f:
        return yaml.safe_load(f)

# %%
cfg = load_config()

# %% [markdown]
# # 2. Setup Exchange

# %%
exchange =  get_exchange(config=cfg)

# %% [markdown]
# # 3. Fetch Data

# %%
df = fetch_data(config=cfg, exchange=exchange)

# %%
df.head
# Out:
# <bound method NDFrame.head of               open    high     low   close        volume
# timestamp
# 2023-01-07   13.51   13.51   13.01   13.10  1.904951e+06
# 2023-01-08   13.10   14.89   12.85   14.45  6.295596e+06
# 2023-01-09   14.46   17.50   14.28   16.25  1.948196e+07
# 2023-01-10   16.25   16.73   15.57   16.20  8.489418e+06
# 2023-01-11   16.20   16.67   15.28   16.36  6.661617e+06
# ...            ...     ...     ...     ...           ...
# 2025-09-28  203.47  211.00  198.00  210.83  2.194260e+06
# 2025-09-29  210.83  214.74  204.58  212.75  3.213099e+06
# 2025-09-30  212.74  213.67  204.29  208.68  3.264781e+06
# 2025-10-01  208.68  222.77  206.31  222.04  4.050261e+06
# 2025-10-02  222.04  233.79  219.52  231.99  4.158639e+06
#
# [1000 rows x 5 columns]>

# %% [markdown]
# # 4. Apply strategy

# %%
r_df = backtest(df, config=cfg)

# %%
# Out:
#              open   high    low  close       volume
# timestamp
# 2023-01-07  13.51  13.51  13.01  13.10   1904950.91
# 2023-01-08  13.10  14.89  12.85  14.45   6295596.12
# 2023-01-09  14.46  17.50  14.28  16.25  19481959.57
# 2023-01-10  16.25  16.73  15.57  16.20   8489417.77
# 2023-01-11  16.20  16.67  15.28  16.36   6661616.67
# ...           ...    ...    ...    ...          ...
# 2023-04-12  22.99  24.48  22.29  23.80  10374263.08
# 2023-04-13  23.81  25.30  23.63  24.43   6063385.78
# 2023-04-14  24.43  25.49  23.73  24.71   6432126.81
# 2023-04-15  24.72  24.80  23.81  24.05   2861426.92
# 2023-04-16  24.05  25.49  23.81  25.34   3471417.67
#
# [100 rows x 5 columns]

# %%
res_df, res_df_short_window, res_df_long_window,  SMA_SHORT, SMA_LONG = apply_mca_dynamic_stoploss_strategy(df, config=cfg)

# %%
res_df.head()
# Out:
#              open   high    low  close       volume
