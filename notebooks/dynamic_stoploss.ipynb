# %% [markdown]
# # 0. Imports

# %%
import yaml
from exchange.exchange_utils import get_exchange, fetch_data
from portfolio.dynamic_stoploss import backtest, plot_backtest
from portfolio.mathematical import plot_equity

# %% [markdown]
# # 1. Load Configs

# %%
def load_config(path="../config.yaml"):
    with open(path, "r") as f:
        return yaml.safe_load(f)

# %%
cfg = load_config()

# %% [markdown]
# # 2. Setup Exchange

# %%
exchange =  get_exchange(config=cfg)

# %% [markdown]
# # 3. Fetch Data

# %%
df = fetch_data(config=cfg, exchange=exchange)

# %% [markdown]
# # 4. Apply strategy

# %%
equity_df, trades_df, final_value, returns = backtest(df, config=cfg)
# Out:
# C:\Users\sharv\Documents\Sharvil\Projects\crypto-trader\portfolio\dynamic_stoploss.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hist_df['SMA_SHORT'] = hist_df['close'].rolling(short_window).mean()
# C:\Users\sharv\Documents\Sharvil\Projects\crypto-trader\portfolio\dynamic_stoploss.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hist_df['SMA_LONG'] = hist_df['close'].rolling(long_window).mean()
# ...

# %%
plot_backtest(df, trades_df, equity_df, config=cfg)

# %%
plot_equity(equity_df)

# %%
print("Final Portfolio Value:", final_value)
print("Returns (%):", returns)
print(trades_df)
# Out:
# Final Portfolio Value: 2805.871284420728
# Returns (%): 180.5871284420728
#     timestamp      price  type
# 0  2023-04-19   28243.65   buy
# 1  2023-06-06   26339.34  sell
# 2  2023-06-29   30472.00   buy
# 3  2023-08-21   26056.00  sell
# 4  2023-10-20   29909.80   buy
# 5  2024-05-15   65235.21  sell
# 6  2024-05-21   69166.62   buy
# 7  2024-06-26   61706.47  sell
# 8  2024-07-30   64628.00   buy
# 9  2024-08-07   61685.99  sell
# 10 2024-09-28   65602.01   buy
# 11 2025-02-19   98305.00  sell
# 12 2025-05-03   94277.62   buy
# 13 2025-09-07  112065.23  sell
# 14 2025-09-19  115685.63   buy
